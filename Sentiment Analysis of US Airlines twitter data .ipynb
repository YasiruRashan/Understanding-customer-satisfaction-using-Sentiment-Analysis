# %% [markdown]
# # Question 01

# %% [markdown]
# <h2>Marketing</h2>
# <h3>Artificial Intelligence in Marketing</h3>
# <br>
# In today's world, people are interacting with different forms of Artificial intelligence in their day-to-day activities. Email spam filtering, song recommendations on Spotify, self-driving cars, chatbots, and virtual assistants such as Siri, Alexa, and Cortana are some common forms of AI applications. These applications can identify their surroundings, manage what they observe, solve problems, and take action to help with tasks to improve the quality of daily life. <br>
#
# AI is becoming more significant in marketing from a strategic standpoint. A growing number of businesses are improving their performance by implementing AI-based platforms (such as Microsoft Cognitive Services, Amazon Lex, Google Assistant, or IBM Watson), including Google, Rare Carat, Spotify, and Netflix. This strategy improves market forecasting and automation while increasing consumer interaction across all marketing channels. As a result, AI has been recognized as the most significant technology for business, with growth projected to reach 126 billion USD by 2025 from 10.1 billion USD in 2018.<br>
#
# There are different use cases in AI marketing as below.
# <br>
#    1. Automated decision-making :
# Based on historical data analysis, AI marketing tools assists businesses in selecting the best marketing strategy to      implement. Different AI algorithms such as Naïve byes, decision trees, and support vector machines are used here.<br><br>
#
#    2. Natural Language Processing (NLP) related applications :
# NLP is a deep learning technology that enables machines to understand human language. Content creation, chatbots, and sentiment analysis of consumer reviews on products/services on social media platforms (Twitter/Facebook) are some applications of NLP used in marketing.<br><br>
#
#    3. Predictive Analysis and behavior analysis of customers :
# AI gives companies an in-depth understanding of their customers using machine learning and big data analysis. Businesses will be able to hyper-personalize encounters and forecast future customers' behavior. This will provide real-time personalized experiences for the customers. According to the research firm Aberdeen. Companies that use predictive analytics to detect client demands can boost organic revenue by 21% year over year, as opposed to an average of 12% without them.<br><br>
#
#    4. AI-enhanced digital advertising :
# AI is a crucial factor when implementing digital advertising methods. These methods place the relevant ads to the target audiences using machine learning algorithms and big data. This is defined as programmatic advertising. Profited ways of productive digital advertising can be achieved through AI technologies.<br><br>
#
#
#
#
#
#
#
#
#
#
# Understanding Customer Satisfaction using Sentiment Analysis on US Airline Twitter Data
# AI marketing strategies can be applied to maintain a healthy customer relationship between customers and the business. There are 05 main types of customer relationships as customer trust, customer satisfaction, customer commitment, customer engagement, and customer loyalty. Out of these, Customer satisfaction is a key factor for the growth of businesses.
# Today, the business world is very competitive. Business firms invest a lot of money and human resources in different ways to comprehend and meet the needs of the customers. Customer satisfaction measures how consumers feel about the products, services, and operations of the company. Many previous pieces of research point out that the quality of the products or services and the happiness of the customers are the most important factors for business performance. To be in the competitive market, business firms should try to explore the requirements of customers and their expectations. However, a lot of business firms failed to achieve the target level of customer satisfaction due to the poor manual analysis of the diverse needs of customers.
# The airline industry is one of the leading industries in the world which provides services to thousands of customers every day. According to the reports from the Federal Aviation Administration Air-Traffic [FAA], 2,246,000 people board flights in the United States of America (USA) every day. These Airlines are highly concerned about customer satisfaction as it is a crucial factor for their existence. Because of that, there is huge competition among the airlines to create a competitive edge. All these Airlines try to maintain a good profile on social media as well.
# The literature on customer service and marketing pays a lot of attention to the causes and effects of customer satisfaction, which is described as "the consumer's assessment of whether a product or service meets or falls on behalf of customer expectations." Modeling customer satisfaction is one of the trending topics among machine learning researchers. They developed a system called the American Customer Satisfaction Index to measure the score levels of customer satisfaction. The literature on service quality suggests several factors that explain satisfaction ratings. The SERVQUAL model was used to measure service quality and customer satisfaction.
# Opinion Mining for Twitter data and building an ensemble sentiment classification system perform well in analyzing Twitter data. This system is based on a Lexicon-based approach which is built using a Lexicon dictionary. This approach can calculate the total of positive sentiments words and negative sentiments words in a text file.
# The discipline of text mining, commonly referred to as text analytics, uses several methods to automatically extract useful information from text. Companies can get benefits, including scalability and dependability, from the autonomous examination of the content of multiple text sources. Due to the availability of textual data formats, which make up about 80% of corporate information, text mining gives businesses significant potential for insights.
# Most of the time, the data on social media platforms are unstructured. It will become difficult to extract customer opinions with manual methods. The Natural language processing (NLP) technique called sentiment analysis comes to solve these issues. Classifying the polarity of the textual data (positive/negative/neutral) is the main task of sentiment analysis. The results of the sentiment analysis help business firms improve their products and services. Sentiment mining uses to compare tweets with predefined corps of subjective words.
#
#
# All these research help to understand the customer satisfaction towards the business services and get insights into the sentiment distribution (positive/negative/neutral).
#
#
#
#
#
#
#
# 2)

# %% [markdown]
# 1. Feature Extraction: TF-IDF (term frequency-inverse document frequency)
# 2. Classification: Support Vector Machine (SVM)

# %% [markdown]
# # Import the required packages

# %%
# for the Basic Operation

import pandas as pd
import numpy as np

# for the Text Preprocessing & Cleaning

from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
import re
from sklearn.model_selection import train_test_split # Split Data into training and testing set 

# for the performance metrix

from sklearn.metrics import classification_report , confusion_matrix , accuracy_score  

# Data visulaization part for the EDA

import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
 
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # Data Collection And Preprocessing

# %%
# Loading the data form CSV file to the Pandas framework
df1 = pd.read_csv('D:\Final Year\Applied AI\Coursework\CW 01\Tweets.csv')

# %%
# Check the first five entries
df1.head(5)
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# ...

# %%
# Check the last five entries
df1.tail(5)
# Out:
#                  tweet_id airline_sentiment  airline_sentiment_confidence  \
# 14635  569587686496825344          positive                        0.3487
# 14636  569587371693355008          negative                        1.0000
# 14637  569587242672398336           neutral                        1.0000
# 14638  569587188687634433          negative                        1.0000
# 14639  569587140490866689           neutral                        0.6771
#
#                negativereason  negativereason_confidence   airline  \
# 14635                     NaN                     0.0000  American
# 14636  Customer Service Issue                     1.0000  American
# 14637                     NaN                        NaN  American
# 14638  Customer Service Issue                     0.6659  American
# 14639                     NaN                     0.0000  American
#
#       airline_sentiment_gold             name negativereason_gold  \
# ...

# %%
# obtain the number of rows and columns of the dataframe
print("Shape of the dataframe is : \n",df1.shape)
# Out:
# Shape of the dataframe is :
#  (14640, 15)

# %%
#  Check the columns of the dataset
print("Columns of the dataset are : \n", df1.columns)
# Out:
# Columns of the dataset are :
#  Index(['tweet_id', 'airline_sentiment', 'airline_sentiment_confidence',
#        'negativereason', 'negativereason_confidence', 'airline',
#        'airline_sentiment_gold', 'name', 'negativereason_gold',
#        'retweet_count', 'text', 'tweet_coord', 'tweet_created',
#        'tweet_location', 'user_timezone'],
#       dtype='object')

# %%
# Check the information about the dataframe
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14640 entries, 0 to 14639
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tweet_id                      14640 non-null  int64
#  1   airline_sentiment             14640 non-null  object
#  2   airline_sentiment_confidence  14640 non-null  float64
#  3   negativereason                9178 non-null   object
#  4   negativereason_confidence     10522 non-null  float64
#  5   airline                       14640 non-null  object
#  6   airline_sentiment_gold        40 non-null     object
#  7   name                          14640 non-null  object
#  8   negativereason_gold           32 non-null     object
#  9   retweet_count                 14640 non-null  int64
#  10  text                          14640 non-null  object
#  11  tweet_coord                   1019 non-null   object
# ...

# %%
# check the no of unique values in each column
print("No of Unique values in each column : \n", df1.nunique())
# Out:
# No of Unique values in each column :
#  tweet_id                        14485
# airline_sentiment                   3
# airline_sentiment_confidence     1023
# negativereason                     10
# negativereason_confidence        1410
# airline                             6
# airline_sentiment_gold              3
# name                             7701
# negativereason_gold                13
# retweet_count                      18
# text                            14427
# tweet_coord                       832
# tweet_created                   14247
# tweet_location                   3081
# user_timezone                      85
# dtype: int64

# %%
# Check the no of null values in each column. In here, we can use both isna() or isnull() functions in Pandas

print ("No of null values in each column : \n", df1.isna().sum())
# Out:
# No of null values in each column :
#  tweet_id                            0
# airline_sentiment                   0
# airline_sentiment_confidence        0
# negativereason                   5462
# negativereason_confidence        4118
# airline                             0
# airline_sentiment_gold          14600
# name                                0
# negativereason_gold             14608
# retweet_count                       0
# text                                0
# tweet_coord                     13621
# tweet_created                       0
# tweet_location                   4733
# user_timezone                    4820
# dtype: int64

# %%
# check the no of null values in each column as a percentage

((df1.isna()).sum() * 100 / df1.index.size).round(2)
# Out:
# tweet_id                         0.00
# airline_sentiment                0.00
# airline_sentiment_confidence     0.00
# negativereason                  37.31
# negativereason_confidence       28.13
# airline                          0.00
# airline_sentiment_gold          99.73
# name                             0.00
# negativereason_gold             99.78
# retweet_count                    0.00
# text                             0.00
# tweet_coord                     93.04
# tweet_created                    0.00
# tweet_location                  32.33
# user_timezone                   32.92
# dtype: float64

# %%
# In here, the three columns such as airline_sentiment_gold,negativereason_gold and tweet_coord contains more than 90% of missing data.
# This will not provide any constructive information.Therefore, I need to delete these three columns.

del df1['airline_sentiment_gold']
del df1['negativereason_gold']
del df1['tweet_coord']

# Check the first five entries
df1.head()

# check the shape of the dataset
# df1.shape
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline        name  \
# 0            NaN                        NaN  Virgin America     cairdin
# 1            NaN                     0.0000  Virgin America    jnardino
# 2            NaN                        NaN  Virgin America  yvonnalynn
# 3     Bad Flight                     0.7033  Virgin America    jnardino
# 4     Can't Tell                     1.0000  Virgin America    jnardino
#
#    retweet_count                                               text  \
# ...

# %% [markdown]
# # Explotary Data Analysis (EDA)

# %% [markdown]
# This approach is used to summerize the characteristics of the dataset by analysing it, often with visualiztion methods

# %%
# check the sentiment distribution of the datset

print("Count of the sentiment type : \n")
print(df1.airline_sentiment.value_counts())

plt.figure(figsize = (10, 8))
graph = sns.countplot(x = 'airline_sentiment', data = df1)
graph.set_title(label = 'Count of the sentiment type', fontsize = 15)
plt.show()
# Out:
# Count of the sentiment type :
#
# negative    9178
# neutral     3099
# positive    2363
# Name: airline_sentiment, dtype: int64

# %%
# check the total no of tweets for each air line 

print("Total number of tweets for each airline :\n",)
print(df1.groupby ('airline')['airline_sentiment'].count())

custom_palette =sns.color_palette('Paired',6)
pd.Series(df1['airline']).value_counts().plot(kind="bar",fontsize=10,color=custom_palette ,figsize=(10,8),title='Total No. of Tweets of each Airline')
plt.xlabel('Airline Name')
plt.ylabel('No.of Tweets')
# Out:
# Total number of tweets for each airline :
#
# airline
# American          2759
# Delta             2222
# Southwest         2420
# US Airways        2913
# United            3822
# Virgin America     504
# Name: airline_sentiment, dtype: int64
# Text(0, 0.5, 'No.of Tweets')

# %%
print("Total number of the sentiment tweets for each airline :")
airlines= ['American','Delta','Southwest','United','US Airways','Virgin America']
for i in airlines :
    print('\n {} : \n'.format(i),df1.loc[df1.airline == i].airline_sentiment.value_counts())
    
fig, axs = plt.subplots(2, 3, figsize=(12, 12))
for i, airline in enumerate(airlines):
    new_df = df1[df1['airline'] == airline]
    count = new_df['airline_sentiment'].value_counts()
    axs[i//3, i%3].bar(['negative', 'neutral', 'positive'], count, color=['pink', 'cyan', 'green'])
    axs[i//3, i%3].set_title('Count of sentiments of ' + airline)
    axs[i//3, i%3].set_ylabel('sentiment Count')
    axs[i//3, i%3].set_xlabel('sentiment')

plt.show()
# Out:
# Total number of the sentiment tweets for each airline :
#
#  American :
#  negative    1960
# neutral      463
# positive     336
# Name: airline_sentiment, dtype: int64
#
#  Delta :
#  negative    955
# neutral     723
# positive    544
# Name: airline_sentiment, dtype: int64
#
#  Southwest :
#  negative    1186
# neutral      664
# positive     570
# Name: airline_sentiment, dtype: int64
#
#  United :
#  negative    2633
# neutral      697
# positive     492
# Name: airline_sentiment, dtype: int64
#
#  US Airways :
#  negative    2263
# neutral      381
# positive     269
# Name: airline_sentiment, dtype: int64
#
#  Virgin America :
#  negative    181
# neutral     171
# positive    152
# Name: airline_sentiment, dtype: int64

# %% [markdown]
# According to the above visualizations, we can see that the negative reviews of each Airlines got the highest values among the other sentiments. Let's explore more information about the negative tweets.

# %%
#Check the reasons for the negative tweets.
print('Reasons for the Negative Tweets :\n')
print(df1.negativereason.value_counts())

plt.figure(figsize = (20, 10))
sns.countplot(x = 'negativereason', data = df1, palette = 'Paired')
plt.title('Reasons for the Negative Tweets', fontsize = 15)
plt.show()
# Out:
# Reasons for the Negative Tweets :
#
# Customer Service Issue         2910
# Late Flight                    1665
# Can't Tell                     1190
# Cancelled Flight                847
# Lost Luggage                    724
# Bad Flight                      580
# Flight Booking Problems         529
# Flight Attendant Complaints     481
# longlines                       178
# Damaged Luggage                  74
# Name: negativereason, dtype: int64

# %%
# check the reasons for negative tweets for each airline

negative_count =df1['negativereason'].value_counts()
def NCount(Airline):
    airlineName =df1[df1['airline']==Airline]
    count= airlineName['negativereason'].value_counts()
    Unique_reason= df1['negativereason'].unique()
    Unique_reason=[x for x in Unique_reason if str(x) != 'nan']
    Reason_frame=pd.DataFrame({'Reasons':Unique_reason})
    Reason_frame['count']=Reason_frame['Reasons'].apply(lambda x: count[x])
    return Reason_frame

def Plot_Reason(airline):
    air = NCount(airline)
    count=air['count']
    Id = range(1,(len(air)+1))
    plt.bar(Id,count, color=['plum','aquamarine','lightcoral','sandybrown','greenyellow','lightsalmon','darkgray','darkcyan','khaki','peru'])
    plt.xticks(Id,air['Reasons'],rotation = 90)
    plt.title('Count of Reasons for '+ airline)
    
plt.figure(2,figsize=(14, 12))
for i in airlines:
    indices= airlines.index(i)
    plt.subplot(2,3,indices+1)
    plt.subplots_adjust(hspace=0.9)
    Plot_Reason(i)

# %% [markdown]
# Late flight is the most common reason for negative tweets in Delta airlines.
# The most common reason for Virgin America, US Airways, United,Southwest and American Airlines is the customer service issue.
# Out of the six airlines, virgin america got the least no of reasons.

# %% [markdown]
# # Most used words in the positive and negative tweets

# %% [markdown]
# Wordcloud can be used to visuliaze the NLP data.The frequency of a word in our text data matches with word size in the wordcloud image. If the word size in the wordcloud is large, it means that the word has high frequency in the text data.

# %%
from wordcloud import WordCloud,STOPWORDS

# %% [markdown]
# <b>Generate the wordcloud image for the positive tweets<b>

# %%
df1_new = df1.loc[df1['airline_sentiment'] == 'positive']
wordset = ' '.join(df1_new['text'])
processed_word = " ".join([word for word in wordset.split()
                            if 'http' not in word
                                and word != 'RT'   #retweet
                                and not word.startswith('@')                               
                            ])

wordcloud_image = WordCloud(stopwords=STOPWORDS,
                      background_color='black',
                      width=6000,
                      height=4000
                     ).generate(processed_word)

plt.figure(1,figsize=(20, 10))
plt.imshow(wordcloud_image)
plt.axis('off')
plt.show()

# %% [markdown]
# <b>Generate the wordcloud image for the negative tweets</b>

# %%
df1_new = df1.loc[df1['airline_sentiment'] == 'negative']
wordset = ' '.join(df1_new['text'])
processed_word = " ".join([word for word in wordset.split()
                            if 'http' not in word
                                and word != 'RT'   #retweet
                                and not word.startswith('@')                               
                            ])

wordcloud_image = WordCloud(stopwords=STOPWORDS,
                      background_color='black',
                      width=6000,
                      height=4000
                     ).generate(processed_word)

plt.figure(1,figsize=(20, 10))
plt.imshow(wordcloud_image)
plt.axis('off')
plt.show()

# %% [markdown]
# Deleting the rows with neural sentiments using drop function

# %%
df1 = df1.query("airline_sentiment != 'neutral'")
df1.drop(df1[df1['airline_sentiment'] == 'neutral'].index, inplace=True)

# %% [markdown]
# Check whether that the rows with neural sentiments have already been deleted

# %%
df1.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 1  570301130888122368          positive                        0.3486
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
# 5  570300767074181121          negative                        1.0000
# 6  570300616901320704          positive                        0.6745
#
#   negativereason  negativereason_confidence         airline        name  \
# 1            NaN                     0.0000  Virgin America    jnardino
# 3     Bad Flight                     0.7033  Virgin America    jnardino
# 4     Can't Tell                     1.0000  Virgin America    jnardino
# 5     Can't Tell                     0.6842  Virgin America    jnardino
# 6            NaN                     0.0000  Virgin America  cjmcginnis
#
#    retweet_count                                               text  \
# ...

# %% [markdown]
# # Label Encoding for the airline sentiments

# %% [markdown]
# The process of label encoding turns categorical variables, which are not numeric, into numerical variables. The process of performing mathematical operations on the categorical data can be done easily using label encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lblencod = LabelEncoder()
lblencod.fit(df1['airline_sentiment'])

df1['encoded_airline_sentiment'] = df1['airline_sentiment'].replace({'negative': 0, 'positive': 1})
df1.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 1  570301130888122368          positive                        0.3486
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
# 5  570300767074181121          negative                        1.0000
# 6  570300616901320704          positive                        0.6745
#
#   negativereason  negativereason_confidence         airline        name  \
# 1            NaN                     0.0000  Virgin America    jnardino
# 3     Bad Flight                     0.7033  Virgin America    jnardino
# 4     Can't Tell                     1.0000  Virgin America    jnardino
# 5     Can't Tell                     0.6842  Virgin America    jnardino
# 6            NaN                     0.0000  Virgin America  cjmcginnis
#
#    retweet_count                                               text  \
# ...

# %% [markdown]
# # Text Preprocessing

# %% [markdown]
# Preprocessing on the twitter text data and cleaning the text data.

# %%
import string
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

def tweet_words(tweet):
    # Remove all punctuation characters
    tweet = tweet.translate(str.maketrans('', '', string.punctuation))
    # Convert to lowercase
    tweet = tweet.lower()
    # Tokenize words
    words = word_tokenize(tweet)
    # Remove stop words
    stops = set(stopwords.words("english"))
    correct_words = [w for w in words if w not in stops]
    # Lemmatize words
    lemmatizer = WordNetLemmatizer()
    lemmatized_words = [lemmatizer.lemmatize(word) for word in correct_words]
    # Join words back into a string
    return " ".join(lemmatized_words)

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')

df1['preprocessed_tweet']=df1['text'].apply(lambda x: tweet_words(x))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Yasiru\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Yasiru\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Yasiru\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Yasiru\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
x = df1.preprocessed_tweet
y = df1.airline_sentiment

#length of the x and y 
print(len(x), len(y))
# Out:
# 11541 11541

# %% [markdown]
# # Split data into train and test set

# %% [markdown]
# As the dataset is large, split the data in to train and test data sets in order of 80 % , 20% ratio

# %%
x_trainset, x_testset, y_trainset, y_testset = train_test_split(x, y, random_state=42)
print(len(x_trainset), len(x_testset))
print(len(y_trainset), len(y_testset))
# Out:
# 8655 2886
# 8655 2886

# %% [markdown]
# # Vectorization

# %% [markdown]
# There are common feature extraction techniques in the NLP.
#  1. TF-IDF Vectorizer
#  2. Bag Of Words (Count Vectorizer)

# %% [markdown]
# 1.Using the TF-IDF vectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
vectorizer.fit(x_trainset)
# Out:
# TfidfVectorizer()

# %%
x_train_tfidf = vectorizer.transform(x_trainset)
x_test_tfidf = vectorizer.transform(x_testset)

# %%
tunned_vector = TfidfVectorizer(stop_words='english', min_df=0.1, max_df=0.7, ngram_range=(1,2),max_features=100)
tunned_vector
# Out:
# TfidfVectorizer(max_df=0.7, max_features=100, min_df=0.1, ngram_range=(1, 2),
#                 stop_words='english')

# %% [markdown]
# # Building the Model

# %% [markdown]
# In here, Support Vector Machine (SVM) is used for predicting sentiments from the tweet data

# %%
#training SVM model with linear kernel
#Support Vector Classification-wrapper around SVM

from sklearn.svm import SVC
model = SVC(kernel='linear', random_state = 10)
model.fit(x_train_tfidf, y_trainset)

#predicting output for test data
prediction = model.predict(x_test_tfidf)

# %%
#accuracy score
accuracy_score(y_testset,prediction)
# Out:
# 0.91995841995842

# %% [markdown]
# # Part D - Evaluation and Testing

# %% [markdown]
# The performance of a trained machine learning model is calculated using performance evaluation metrics. This lets you determine how well your machine learning model will perform with a dataset that it has never seen before. There are numerous performance evaluation indicators which can be used to measure the performance of the machine learning models.<br>
#
# * <b>For Regression based machine learning models</b>: R2 Score and Explained Variance
# * <b>For Classification based machine learning models</b>: Classification Report and Confusion Matrix
#
# As the Liner SVM Classification model is used in the implementation, the performance evaluation indicators will be the classification report and the confusion matrix
#
# 1. Confusion Matrix:
#
# This is a method used to evaluate the performance of the machine learning models. The purpose of this metric is to count number of instances of class 1 are categorized as class 2. For an example using the implementation, how many times the built model is getting confused the positive tweet with negative tweet.
#
# <img src="D:\Final Year\Applied AI\Coursework\CW 01\Images" alt="img01" />

# %%
#building confusion matrix
cfs_matrix = confusion_matrix(y_testset, prediction)
cfs_matrix
# Out:
# array([[2252,   71],
#        [ 160,  403]], dtype=int64)

# %%
# plot confusion matrix 

cm= confusion_matrix(y_testset, prediction)
plt.figure(figsize=(10,6))
sentiment_classes = ['Negative','Positive']
sns.heatmap(cm, cmap=plt.cm.Blues, annot=True, fmt='d', 
            xticklabels=sentiment_classes,
            yticklabels=sentiment_classes)
plt.title('Confusion matrix', fontsize=16)
plt.xlabel('Actual label', fontsize=12)
plt.ylabel('Predicted label', fontsize=12)
plt.show()

# %%
report = classification_report(y_testset, prediction)
print("Classification Report :\n -------------------\n",report)
# Out:
# Classification Report :
#  -------------------
#                precision    recall  f1-score   support
#
#     negative       0.93      0.97      0.95      2323
#     positive       0.85      0.72      0.78       563
#
#     accuracy                           0.92      2886
#    macro avg       0.89      0.84      0.86      2886
# weighted avg       0.92      0.92      0.92      2886

# %% [markdown]
# # Predicts the sentiment of the tweets using built model

# %%
tweet = ["@VirginAmerica I'm disappointed that the agent at the designated silver status check in line @Dulles_Airport closed to assist all pasengers"]
input_tweet = vectorizer.transform(tweet)
prediction = model.predict(input_tweet)
print(prediction)
# Out:
# ['negative']

# %%
tweet = ["@VirginAmerica “friendly staff comfortable flight experience”"]
input_tweet = vectorizer.transform(tweet)
prediction = model.predict(input_tweet)
print(prediction)
# Out:
# ['positive']
